# %% [markdown]
# <a href="https://colab.research.google.com/github/vg11072001/Python-programming/blob/main/oops_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Resources

# %% [markdown]
# * [GFG | Python OOP](https://www.geeksforgeeks.org/python-classes-and-objects/?ref=lbp)
#
# * [OOP in Python](https://www.youtube.com/watch?v=qiSCMNBIP2g)
#
# * [Notes of OOP](https://github.com/sauravraghuvanshi/Placement-Prepration/tree/main/Module%201%20-%20Python%20Programming/5.%20Python%20Object%20Oriented%20Programming)
#
# *   Love Babbar for **concepts**:
#
#      [Part 1](https://youtu.be/i_5pvt7ag7E) -[Slides](https://drive.google.com/file/d/1h-4RdVIQCNu_loshweVu5TvqvYxHTY2d/view)
#
#      [Part 2](https://www.youtube.com/watch?v=b3GccK5_KSQ) - [Slides](https://drive.google.com/file/d/1L5Syt7UWG4FJBDth6tfoBn8FfuEMGLUL/view)
#
#   [Mind Map](https://whimsical.com/object-oriented-programming-cheatsheet-by-love-babbar-YbSgLatbWQ4R5paV7EgqFw)

# %% [markdown]
# ## OOP

# %% [markdown]
# ### Object and Class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Computer:
  def config(self):
    print("i5, 16gb, 1TB")

comp1 = Computer()

print(type(comp1))
print(type(int))
print(type(str))

Computer.config(comp1)
# Out:
# <class '__main__.Computer'>
# <class 'type'>
# <class 'type'>
# i5, 16gb, 1TB

# %%
class Computer:
  def config(self):
    print("i5, 16gb, 1TB")

comp1 = Computer()
comp2 = Computer()

Computer.config(comp1)
comp1.config()
# Out:
# i5, 16gb, 1TB
# i5, 16gb, 1TB

# %% [markdown]
# ### __init_ method
# or we can say constructor using init method

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Computer:
  def __init__(self):
    print("in init")

  def config(self):
    print("i5, 16gb, 1TB")

comp1 = Computer()
comp2 = Computer()

comp1.config()
# Out:
# in init
# in init
# i5, 16gb, 1TB

# %%
class Computer:
  def __init__(self, cpu, ram):
    self.cpu = cpu
    self.ram = ram

  def config(self):
    print("Config is", self.cpu, self.ram)

comp1 = Computer("i5", 16)
comp2 = Computer("Ryzen 3", 8)

comp1.config()
comp2.config()
# Out:
# <__main__.Computer object at 0x7fea00fa8a90> i5 16
# <__main__.Computer object at 0x7fea00fa8690> Ryzen 3 8

# %% [markdown]
# ### Constructor and Self

# %%
class Computer:
  pass

c1 = Computer()
print(id(c1))

c2 = Computer()
print(id(c2))
# Out:
# 140643015728976
# 140643014445712

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Computer:
  def __init__(self):
    self.name = "Navin"
    self.age = 20

  def update(self):
    self.age = 30

c1 = Computer()
c2 = Computer()

c1.name = "Vanshika"
c1.age = 19

print(c1.name)
print(c2.name)
# Out:
# Vanshika
# Navin

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
c1.update()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# compare
class Computer:
  def __init__(self):
    self.name = "Navin"
    self.age = 20

  def update(self):
    self.age = 30

  def compare(self, other):
    if self.age ==other.age:
      return True
    else:
      return False

c1 = Computer()
c2 = Computer()

if c1.compare(c2):
  print("They are same")
# Out:
# They are same

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Types of Variable

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Car:

  wheels = 4   

  def __init__(self):
    self.mil =10
    self.com ="BMW"

c1 = Car()
c2 = Car()
c1.mil = 8

print(c1.com, c1.mil, c1.wheels)
print(c2.com, c2.mil, c2.wheels)
# Out:
# BMW 8 4
# BMW 10 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Car:

  wheels = 4   

  def __init__(self):
    self.mil =10
    self.com ="BMW"

c1 = Car()
c2 = Car()
c1.mil = 8

Car.wheels =5

print(c1.com, c1.mil, c1.wheels)
print(c2.com, c2.mil, c2.wheels)
# Out:
# BMW 8 5
# BMW 10 5

# %% [markdown]
# ### Types of Methods

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1 Instance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# means Getter or setter

# %% [markdown]
# 2 Class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# @ - decorator

# %% [markdown]
# 3 Static

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Inner class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class B(A)

# %% [markdown]
# #### Multilevel inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class C(B)

# %% [markdown]
# #### Multiple inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class C(A,B)

# %% [markdown]
# ### Constructor in Inheritance and Methods resoultion order(MRO)

# %%
class A:
  
  def feature1(self):
    print("Feature1 working")

# %% [markdown]
# ### Polymorphism

# %% [markdown]
# #### Duck Typing

# %% [markdown]
# Duck typing here refers to Execute

# %% [markdown]
# #### Operator overloading

# %% [markdown]
# #### Method overloading and method overrinding

# %% [markdown]
# ![image.png](data:image/png;base64,...)
